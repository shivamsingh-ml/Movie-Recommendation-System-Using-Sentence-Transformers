# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\shiva\OneDrive\Desktop\Projects\LLM based Recommendation System\dataset\netflix_titles.csv")
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
def create_textual_representation(row):
    textual_representation = f"""
    Type: {row['type']},
    Title: {row['title']},
    Director: {row['director']},
    Cast: {row['cast']},
    Released: {row['release_year']},
    Genres: {row['listed_in']}
    Description: {row['description']}"""
    return textual_representation

# %%
df['textual_representation'] = df.apply(create_textual_representation, axis=1)

# %%
print(df['textual_representation'].values[0])
# Out:
#     Type: Movie,
#     Title: Dick Johnson Is Dead,
#     Director: Kirsten Johnson,
#     Cast: nan,
#     Released: 2020,
#     Genres: Documentaries
#     Description: As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
import faiss
import numpy as np

dim  = 384
index = faiss.IndexFlatL2(dim)

X = np.zeros((len(df['textual_representation']), dim), dtype='float32')

# %%
for i, representation in enumerate(df['textual_representation']):
    if i % 50 == 0:
        print('Processed', str(i), 'instances')
    
    embedding = model.encode(representation)
    X[i] = np.array(embedding)
    
index.add(X)
# Out:
# Processed 0 instances
# Processed 50 instances
# Processed 100 instances
# Processed 150 instances
# Processed 200 instances
# Processed 250 instances
# Processed 300 instances
# Processed 350 instances
# Processed 400 instances
# Processed 450 instances
# Processed 500 instances
# Processed 550 instances
# Processed 600 instances
# Processed 650 instances
# Processed 700 instances
# Processed 750 instances
# Processed 800 instances
# Processed 850 instances
# Processed 900 instances
# Processed 950 instances
# Processed 1000 instances
# Processed 1050 instances
# Processed 1100 instances
# Processed 1150 instances
# Processed 1200 instances
# Processed 1250 instances
# Processed 1300 instances
# Processed 1350 instances
# Processed 1400 instances
# Processed 1450 instances
# Processed 1500 instances
# Processed 1550 instances
# Processed 1600 instances
# Processed 1650 instances
# Processed 1700 instances
# Processed 1750 instances
# Processed 1800 instances
# Processed 1850 instances
# Processed 1900 instances
# Processed 1950 instances
# Processed 2000 instances
# Processed 2050 instances
# Processed 2100 instances
# Processed 2150 instances
# Processed 2200 instances
# Processed 2250 instances
# Processed 2300 instances
# Processed 2350 instances
# Processed 2400 instances
# Processed 2450 instances
# Processed 2500 instances
# Processed 2550 instances
# Processed 2600 instances
# Processed 2650 instances
# Processed 2700 instances
# Processed 2750 instances
# Processed 2800 instances
# Processed 2850 instances
# Processed 2900 instances
# Processed 2950 instances
# Processed 3000 instances
# Processed 3050 instances
# Processed 3100 instances
# Processed 3150 instances
# Processed 3200 instances
# Processed 3250 instances
# Processed 3300 instances
# Processed 3350 instances
# Processed 3400 instances
# Processed 3450 instances
# Processed 3500 instances
# Processed 3550 instances
# Processed 3600 instances
# Processed 3650 instances
# Processed 3700 instances
# Processed 3750 instances
# Processed 3800 instances
# Processed 3850 instances
# Processed 3900 instances
# Processed 3950 instances
# Processed 4000 instances
# Processed 4050 instances
# Processed 4100 instances
# Processed 4150 instances
# Processed 4200 instances
# Processed 4250 instances
# Processed 4300 instances
# Processed 4350 instances
# Processed 4400 instances
# Processed 4450 instances
# Processed 4500 instances
# Processed 4550 instances
# Processed 4600 instances
# Processed 4650 instances
# Processed 4700 instances
# Processed 4750 instances
# Processed 4800 instances
# Processed 4850 instances
# Processed 4900 instances
# Processed 4950 instances
# Processed 5000 instances
# Processed 5050 instances
# Processed 5100 instances
# Processed 5150 instances
# Processed 5200 instances
# Processed 5250 instances
# Processed 5300 instances
# Processed 5350 instances
# Processed 5400 instances
# Processed 5450 instances
# Processed 5500 instances
# Processed 5550 instances
# Processed 5600 instances
# Processed 5650 instances
# Processed 5700 instances
# Processed 5750 instances
# Processed 5800 instances
# Processed 5850 instances
# Processed 5900 instances
# Processed 5950 instances
# Processed 6000 instances
# Processed 6050 instances
# Processed 6100 instances
# Processed 6150 instances
# Processed 6200 instances
# Processed 6250 instances
# Processed 6300 instances
# Processed 6350 instances
# Processed 6400 instances
# Processed 6450 instances
# Processed 6500 instances
# Processed 6550 instances
# Processed 6600 instances
# Processed 6650 instances
# Processed 6700 instances
# Processed 6750 instances
# Processed 6800 instances
# Processed 6850 instances
# Processed 6900 instances
# Processed 6950 instances
# Processed 7000 instances
# Processed 7050 instances
# Processed 7100 instances
# Processed 7150 instances
# Processed 7200 instances
# Processed 7250 instances
# Processed 7300 instances
# Processed 7350 instances
# Processed 7400 instances
# Processed 7450 instances
# Processed 7500 instances
# Processed 7550 instances
# Processed 7600 instances
# Processed 7650 instances
# Processed 7700 instances
# Processed 7750 instances
# Processed 7800 instances
# Processed 7850 instances
# Processed 7900 instances
# Processed 7950 instances
# Processed 8000 instances
# Processed 8050 instances
# Processed 8100 instances
# Processed 8150 instances
# Processed 8200 instances
# Processed 8250 instances
# Processed 8300 instances
# Processed 8350 instances
# Processed 8400 instances
# Processed 8450 instances
# Processed 8500 instances
# Processed 8550 instances
# Processed 8600 instances
# Processed 8650 instances
# Processed 8700 instances
# Processed 8750 instances
# Processed 8800 instances

# %%
faiss.write_index(index, 'index')

# %%
index = faiss.read_index('index')

# %%
favorite_movie = df.iloc[1358]
print(favorite_movie['textual_representation'])
# Out:
#     Type: Movie,
#     Title: Shutter Island,
#     Director: Martin Scorsese,
#     Cast: Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley, Max von Sydow, Michelle Williams, Emily Mortimer, Patricia Clarkson, Jackie Earle Haley, Ted Levine, John Carroll Lynch, Elias Koteas,
#     Released: 2010,
#     Genres: Thrillers
#     Description: A U.S. marshal's troubling visions compromise his investigation into the disappearance of a patient from a hospital for the criminally insane.

# %%
favorite_movie_embedding = model.encode(favorite_movie['textual_representation'])
favorite_movie_embedding = np.array([favorite_movie_embedding], dtype='float32')

# %%
D, I = index.search(favorite_movie_embedding, 5)

# %%
for match in df['textual_representation'][I.flatten()]:
    print(match)
# Out:
#     Type: Movie,
#     Title: Shutter Island,
#     Director: Martin Scorsese,
#     Cast: Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley, Max von Sydow, Michelle Williams, Emily Mortimer, Patricia Clarkson, Jackie Earle Haley, Ted Levine, John Carroll Lynch, Elias Koteas,
#     Released: 2010,
#     Genres: Thrillers
#     Description: A U.S. marshal's troubling visions compromise his investigation into the disappearance of a patient from a hospital for the criminally insane.
#
#     Type: Movie,
#     Title: Black Island,
#     Director: Miguel Alexandre,
#     Cast: Philip Froissant, Alice Dwyer, Hanns Zischler, Mercedes Müller, Sammy Scheuritzel, Lieselotte Voß, Katharina Schütz, Jodie Leslie Ahlborn, Marco Wittorf, Ilknur Boyraz,
#     Released: 2021,
#     Genres: International Movies, Thrillers
#     Description: The dark secrets of a seemingly peaceful island threaten to swallow up an orphaned student when he grows close to a mysterious new teacher.
#
#     Type: Movie,
#     Title: Inception,
#     Director: Christopher Nolan,
#     Cast: Leonardo DiCaprio, Joseph Gordon-Levitt, Elliot Page, Tom Hardy, Ken Watanabe, Dileep Rao, Cillian Murphy, Tom Berenger, Marion Cotillard, Pete Postlethwaite, Michael Caine, Lukas Haas,
#     Released: 2010,
#     Genres: Action & Adventure, Sci-Fi & Fantasy, Thrillers
#     Description: A troubled thief who extracts secrets from people's dreams takes one last job: leading a dangerous mission to plant an idea in a target's subconscious.
#
#     Type: Movie,
#     Title: The Da Vinci Code,
#     Director: Ron Howard,
#     Cast: Tom Hanks, Audrey Tautou, Ian McKellen, Jean Reno, Paul Bettany, Alfred Molina, Jürgen Prochnow, Jean-Yves Berteloot, Etienne Chicot, Jean-Pierre Marielle,
#     Released: 2006,
#     Genres: Thrillers
#     Description: When the curator of the Louvre is killed, a Harvard professor and a cryptographer must untangle a web of deceit involving works of Leonardo da Vinci.
#
#     Type: Movie,
#     Title: Black Beach,
#     Director: Esteban Crespo,
#     Cast: Raúl Arévalo, Candela Peña, Paulina García, Claude Musungayi, Babou Cham, Lidia Nené, Melina Matthews, Emilio Buale, Mulie Jarju, Jimmy Castro, Fenda Drame, Dairon Tallon, Teresita Evuy, Olivier Bony,
#     Released: 2020,
#     Genres: Action & Adventure, International Movies
#     Description: A lawyer with a promising future is forced to deep dive into his past when he agrees to negotiate with an old friend turned kidnapper.
